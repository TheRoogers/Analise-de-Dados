# %%
# !python --version
# Out:
# Python 3.8.3

# %%
# !pip install pymongo[srv]

# %%
import pymongo
from pymongo import MongoClient

# %%
pymongo.version
# Out:
# '3.11.1'

# %%
client = pymongo.MongoClient("mongodb+srv://admin:205450917@cluster0.dhs7a.gcp.mongodb.net/anatel?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['anatel',
#  'covid',
#  'frutas',
#  'mercearia',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
db = client.anatel

# %%
db.minas.count_documents({})
# Out:
# 389000

# %%
list(db.minas.find().limit(5))
# Out:
# [{'_id': ObjectId('5fbeea6fe9a9b438a4b6c9f8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fbeea6fe9a9b438a4b6c9f9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 8},
#  {'_id': ObjectId('5fbeea6fe9a9b438a4b6c9fa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
# ...

# %%
db.minas.find_one(sort=[("QtdeSolic", -1)])
# Out:
# {'_id': ObjectId('5fbeeaa6e9a9b438a4b8e9fe'),
#  'DataExtracao': datetime.datetime(2016, 4, 19, 0, 0),
#  'Ano': 2013,
#  'Mes': 12,
#  'CanalEntrada': 'Call Center',
#  'Condicao': 'Nova',
#  'GrupoEconNorm': 'OI',
#  'Tipo': 'Reclamação',
#  'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#  'Modalidade': 'Local',
#  'Motivo': 'Reparo',
#  'UF': 'MG',
#  'QtdeSolic': 4164}

# %%
foo = db.minas.find_one(sort=[("QtdeSolic", 1)])
print(foo['QtdeSolic'])
# Out:
# 1

# %%
var = db.minas.find_one(sort=[("QtdeSolic", 1)])
menorQtde = var['QtdeSolic']
list(db.minas.find({'QtdeSolic': menorQtde}))
# Out:
# [{'_id': ObjectId('5fbeea6fe9a9b438a4b6c9fa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbeea6fe9a9b438a4b6c9fb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fbeea6fe9a9b438a4b6c9fc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
# ...

# %%
pipeline = [
    { "$group": { "_id": "$Servico", "contagem": { "$sum": "$QtdeSolic"  } } },
    { "$sort": { "contagem": -1 }}
]

list(db.minas.aggregate(pipeline))
# Out:
# [{'_id': 'Móvel Pessoal', 'contagem': 1082107},
#  {'_id': 'Celular Pós-Pago', 'contagem': 560534},
#  {'_id': 'Serviço Telefônico Fixo Comutado - STFC', 'contagem': 532808},
#  {'_id': 'Telefone Fixo', 'contagem': 353545},
#  {'_id': 'TV por Assinatura', 'contagem': 316279},
#  {'_id': 'Serviço de Comunicação Multimídia', 'contagem': 254462},
#  {'_id': 'Banda Larga Fixa', 'contagem': 236336},
#  {'_id': 'Celular Pré-Pago', 'contagem': 223142},
#  {'_id': 'Serviços da Anatel', 'contagem': 38064},
#  {'_id': 'Radiodifusão (Rádio e TV)', 'contagem': 6036},
#  {'_id': 'Outros', 'contagem': 2926},
#  {'_id': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'contagem': 2824},
#  {'_id': 'Rádio do Cidadão (PX)', 'contagem': 2653},
#  {'_id': 'Radioamador (PY)', 'contagem': 2519},
#  {'_id': 'Troncalizado (Trunking)', 'contagem': 2286},
#  {'_id': 'Limitado Privado', 'contagem': 919},
#  {'_id': 'Serviço Móvel Aeronáutico', 'contagem': 109},
# ...

# %%
reclamacoes = list(db.minas.find({ "Tipo": "Reclamação"}))
len(reclamacoes)
# Out:
# 359914

# %%
list(db.minas.distinct('Tipo'))
# Out:
# ['Denúncia', 'Elogio', 'Pedido de Informação', 'Reclamação', 'Sugestão']
